# %%
from app.app import App
import random as rd
import itertools
import numpy as np
import time
import matplotlib.pyplot as plt

from utils.population import Population
from utils.pipe import Pipe
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
window_width, window_height = 800, 600

n_birds = 32 # Number of birds in our population
n_reproducers = int(np.ceil(0.10 * n_birds)) # Number of birds that are allowed to reproduce
print(f"n_reproducers {n_reproducers}")
x_birds = 200
# reproducers = []
mutation_rate = 0.02

dt = 1 # ms
time_since_last_pipe = 0
dist_between_pipes = 400
floor_height = 50
floor_frontier = (x_birds, window_height - floor_height)
ceiling_frontier = (x_birds, 0)

max_distances = []
n_pipes_created = []
# Out:
# n_reproducers 4

# %%
# This Function takes the indices of the reproducers after the generation test and returns a list of new genomes for the next generation.
def get_next_generation_genomes(population):
    # Getting the best birds' genomes
    print("Getting the best birds' genomes")
    selected_genomes = [population.brains[reproducer_index].genome for reproducer_index in population.reproducers]
    print(f"Selected {len(selected_genomes)} Genomes.")

    # Creating n_birds new genomes by crossing over the selected genomes
    print("Creating n_birds new genomes by crossing over the selected genomes")
    new_genomes = []
    for i in range(n_birds):
        i1 = np.random.randint(0, len(selected_genomes))
        i2 = np.random.randint(0, len(selected_genomes))
        while i1 == i2: # making sure i1 and i2 are different
            i2 = np.random.randint(0, len(selected_genomes))
        
        genome_parent1 = selected_genomes[i1]
        genome_parent2 = selected_genomes[i2]

        # crossover_point = np.random.randint(0, len(genome_parent1))
        crossover_rate = rd.random()
        crossover_points = {k: int(crossover_rate * genome_parent1[k].size) for k in genome_parent1.keys()}

        # To create the genome of the child we take each layers of both parents and we take the weights
        # of the first parent's genome until the crossover point and we finish with the second parent's
        # genome.
        genome_child = {
            k: np.concatenate((
                genome_parent1[k].flatten()[:crossover_points[k]],
                genome_parent2[k].flatten()[crossover_points[k]:]
            )).reshape(genome_parent1[k].shape)
            for k in genome_parent1.keys()
        }
        new_genomes.append(genome_child)

    # Mutations on the newborns
    print(f"Mutations on the newbords (mutation rate: {mutation_rate})")
    # The mutation is a natural process when you create an new child. Here we do random mutations
    # with the probability of mutation_rate, which means each weight or bias of the neural
    # network has a probability of mutation_rate to be randomly modified. To minimise the
    # complexity, we create a mutation_mask which decides which values will be modified. Then we
    # create an array where all the values have been modified, and finally we update the values
    # of the layer which have been chosen by the mutation_mask to give them the value of the
    # newly created array mutated_values.
    mutated_genomes = []
    for new_genome in new_genomes:
        mutated_genome = {}
        for k in new_genome:
            layer = new_genome[k].copy()
            # print(f"layer.shape {layer.shape}")
            mutation_mask = np.random.rand(len(layer)) < mutation_rate
            mutated_values = np.random.uniform(low=np.min(layer), high=np.max(layer), size=layer.shape)
            # print(f"mutated_values.shape {mutated_values.shape}")
            layer[mutation_mask] = mutated_values[mutation_mask]
            mutated_genome[k] = layer
        mutated_genomes.append(mutated_genome)

    return mutated_genomes

# %%
# This Function finds the next pipe coming and returns its distance to the birds and its height
def find_next_pipe(pipes: list[Pipe], x_birds: int):
    coming_pipes = [pipe for pipe in pipes if pipe.x + pipe.width > x_birds]  # Getting the coming pipes depending on their x attribute
    next_pipe = coming_pipes[0]  # The first one is the firstly added one, so the really next one
    next_pipe_dist = next_pipe.x - x_birds  # Getting its distance on the x axis
    next_pipe_height = next_pipe.height  # Getting its height
    return next_pipe_dist, next_pipe_height

# %%
def simulate(n_generations):
    # Initialising variables
    window_width, window_height = 800, 600

    n_birds = 32 # Number of birds in our population
    n_reproducers = int(np.ceil(0.10 * n_birds)) # Number of birds that are allowed to reproduce
    print(f"n_reproducers {n_reproducers}")
    x_birds = 200
    # reproducers = []
    mutation_rate = 0.02
    
    dt = 1 # ms
    time_since_last_pipe = 0
    dist_between_pipes = 400
    floor_height = 50
    floor_frontier = (x_birds, window_height - floor_height)
    ceiling_frontier = (x_birds, 0)
    
    max_distances = []
    n_pipes_created = []
    
    genomes = None # Initial genome of the birds will be randomly generated

    # Launching Simulation
    for i in range(n_generations):
        print("#"*150)
        print(f"GENERATION {i}")
        print("#"*150)
        # Creating the Population
        print("Creating the Population")
        population = Population(n_birds=n_birds, n_reproducers=n_reproducers, genomes=genomes)
        # Generating the Pipes²
        print("Generating the Pipes")
        pipe1 = Pipe(window_dim=(window_width, window_height), height=300)
        pipe_speed = pipe1.speed
        pipes = [pipe1]
    
        # Used just for not choosing several times the same reproducers
        reproducers_selected = False
    
        # Used to record the performance of the best bird of the current generation
        max_dist = 0
    
        # Launching the Generation Simulation
        print("Launching the Generation Simulation")
        running = True
        while running:
            # Moving the pipes
            for pipe in pipes:
                pipe.move()
            # Generating new pipes (no acceleration of the pipes)
            dist_since_last_pipe = (pipe_speed / dt) * time_since_last_pipe
            if dist_since_last_pipe >= dist_between_pipes:
                new_pipe_height = rd.randint(0, window_height - 200 - floor_height)
                new_pipe = Pipe(window_dim=(window_width, window_height), height=new_pipe_height)
                pipes.append(new_pipe)
                time_since_last_pipe = 0
            
            # Making the birds fly
            population.fly()
            # Updating the max_dist with the distance done after this time step
            max_dist += pipe_speed * dt
    
            # Collecting information about the next coming pipe
            next_pipe_dist, next_pipe_height = find_next_pipe(pipes, x_birds)
            # print("Making the Birds Flap")
            outputs = []
            for i, brain in enumerate(population.brains):
                input = population.birds[i,:]
                output = brain.get_response(input, next_pipe_dist, next_pipe_height)
                outputs.append(output.detach().numpy()[0])  # output is a tensor with 1 elt so we detach it, convert to numpy and then get the only elt to get a float
    
            flap_indices = [i for i, value in enumerate(outputs) if value > 0]
            # Some birds might be dead so we don't take them
            real_flap_indices = [ind for ind in flap_indices if population.birds[ind, 3]]
            # print(f"{len(flap_indices)} Birds are selected to flap but {len(real_flap_indices)} are alive.")
            population.flap(index=real_flap_indices)
    
            # Collision
            global_frontier = [floor_frontier] + [ceiling_frontier] + list(itertools.chain(*[curr_pipe.frontier for curr_pipe in pipes])) # concatenating all the frontiers
            # print(f"frontier {frontier}")
            reproducers = population.kill(global_frontier, floor_frontier, ceiling_frontier)
    
            # Condition for stopping the simulation
            running = False if population.all_birds_dead() else True
    
            # making time run
            time_since_last_pipe += dt
    
        # Printing the best distance
        print(f"The best Bird of Generation {i} achieved a distance of {max_dist}")
        max_distances.append(max_dist)
        n_pipes_created.append(len(pipes))
        
        # Creating the next generation
        print("Creating the next generation")
        # genomes = mutated_genomes
        genomes = get_next_generation_genomes(population=population)

    return max_distances, n_pipes_created

# %%
# n_generations = 5
# start_time = time.time()
# max_distances, n_pipes_created = simulate(n_generations)
# end_time = time.time()

# %%
# print(f"Best Distances: {max_distances}")
# print(f"Time Taken: {end_time - start_time}")

# plt.plot(max_distances, 'o-')
# plt.title('Distance reached by Generation')
# plt.xlabel('Generation')
# plt.ylabel('Distance reached by the best Bird')
# plt.show()

# plt.plot(n_pipes_created, 'o-')
# plt.title('Number of Pipes created by Generation')
# plt.xlabel('Generation')
# plt.ylabel('Number of pipes created')
# plt.show()

# %%
def simulate_for(duration):
    # Initialising variables
    window_width, window_height = 800, 600

    n_birds = 64 # Number of birds in our population
    percentage_reproducers = 0.1
    n_reproducers = int(np.ceil(percentage_reproducers * n_birds)) # Number of birds that are allowed to reproduce
    print(f"n_reproducers {n_reproducers}")
    x_birds = 200
    # reproducers = []
    mutation_rate = 0.02
    
    dt = 1 # ms
    time_since_last_pipe = 0
    dist_between_pipes = 400
    floor_height = 50
    floor_frontier = (x_birds, window_height - floor_height)
    ceiling_frontier = (x_birds, 0)
    
    max_distances = []
    n_pipes_created = []
    
    genomes = None # Initial genome of the birds will be randomly generated

    n_gen = 0  # Number of current generation
    start_time = time.time()
    # Launching Simulation
    while time.time() < start_time + duration:
        print(f"{time.time()} vs. {start_time + duration}")
        print(f"remaining: {round(start_time + duration - time.time())}")
    # for i in range(n_generations):
        print("#"*150)
        print(f"GENERATION {n_gen}")
        print("#"*150)
        # Creating the Population
        print("Creating the Population")
        population = Population(n_birds=n_birds, n_reproducers=n_reproducers, genomes=genomes)
        # Generating the Pipes²
        print("Generating the Pipes")
        pipe1 = Pipe(window_dim=(window_width, window_height), height=300)
        pipe_speed = pipe1.speed
        pipes = [pipe1]
    
        # Used just for not choosing several times the same reproducers
        reproducers_selected = False
    
        # Used to record the performance of the best bird of the current generation
        max_dist = 0
    
        # Launching the Generation Simulation
        print("Launching the Generation Simulation")
        running = True
        while running:
            # Moving the pipes
            for pipe in pipes:
                pipe.move()
            # Generating new pipes (no acceleration of the pipes)
            dist_since_last_pipe = (pipe_speed / dt) * time_since_last_pipe
            if dist_since_last_pipe >= dist_between_pipes:
                new_pipe_height = rd.randint(0, window_height - 200 - floor_height)
                new_pipe = Pipe(window_dim=(window_width, window_height), height=new_pipe_height)
                pipes.append(new_pipe)
                time_since_last_pipe = 0
            
            # Making the birds fly
            population.fly()
            # Updating the max_dist with the distance done after this time step
            max_dist += pipe_speed * dt
    
            # Collecting information about the next coming pipe
            next_pipe_dist, next_pipe_height = find_next_pipe(pipes, x_birds)
            # print("Making the Birds Flap")
            outputs = []
            for i, brain in enumerate(population.brains):
                input = population.birds[i,:]
                output = brain.get_response(input, next_pipe_dist, next_pipe_height)
                outputs.append(output.detach().numpy()[0])  # output is a tensor with 1 elt so we detach it, convert to numpy and then get the only elt to get a float
    
            flap_indices = [i for i, value in enumerate(outputs) if value > 0]
            # Some birds might be dead so we don't take them
            real_flap_indices = [ind for ind in flap_indices if population.birds[ind, 3]]
            # print(f"{len(flap_indices)} Birds are selected to flap but {len(real_flap_indices)} are alive.")
            population.flap(index=real_flap_indices)
    
            # Collision
            global_frontier = [floor_frontier] + [ceiling_frontier] + list(itertools.chain(*[curr_pipe.frontier for curr_pipe in pipes])) # concatenating all the frontiers
            # print(f"frontier {frontier}")
            reproducers = population.kill(global_frontier, floor_frontier, ceiling_frontier)
    
            # Condition for stopping the simulation
            running = False if population.all_birds_dead() else True
    
            # making time run
            time_since_last_pipe += dt

        n_gen += 1
    
        # Printing the best distance
        print(f"The best Bird of Generation {i} achieved a distance of {max_dist}")
        max_distances.append(max_dist)
        n_pipes_created.append(len(pipes))

        print(f"RESULTS: Created {len(pipes)} pipes, reached a distance of {max_dist}")
        
        # Creating the next generation
        print("Creating the next generation")
        # genomes = mutated_genomes
        genomes = get_next_generation_genomes(population=population)

            

    return max_distances, n_pipes_created

# %%
sec = 1
minutes = 60 * sec
hours = 60 * minutes
day = 24 * hours

# %%
start_time = time.time()
max_distances, n_pipes_created = simulate_for(30 * minutes)
end_time = time.time()
# Out:
# n_reproducers 7
# 1721988105.7450309 vs. 1721989905.7450309
# remaining: 1800
# ######################################################################################################################################################
# GENERATION 0
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 63 achieved a distance of 581
# RESULTS: Created 2 pipes, reached a distance of 581
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988108.5007894 vs. 1721989905.7450309
# remaining: 1797
# ######################################################################################################################################################
# GENERATION 1
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 581
# RESULTS: Created 2 pipes, reached a distance of 581
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988110.5748386 vs. 1721989905.7450309
# remaining: 1795
# ######################################################################################################################################################
# GENERATION 2
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 679
# RESULTS: Created 3 pipes, reached a distance of 679
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988113.1065526 vs. 1721989905.7450309
# remaining: 1793
# ######################################################################################################################################################
# GENERATION 3
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 637
# RESULTS: Created 3 pipes, reached a distance of 637
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988115.218975 vs. 1721989905.7450309
# remaining: 1791
# ######################################################################################################################################################
# GENERATION 4
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 483
# RESULTS: Created 2 pipes, reached a distance of 483
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988116.5962126 vs. 1721989905.7450309
# remaining: 1789
# ######################################################################################################################################################
# GENERATION 5
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 588
# RESULTS: Created 2 pipes, reached a distance of 588
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988118.41904 vs. 1721989905.7450309
# remaining: 1787
# ######################################################################################################################################################
# GENERATION 6
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 630
# RESULTS: Created 3 pipes, reached a distance of 630
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988120.6663883 vs. 1721989905.7450309
# remaining: 1785
# ######################################################################################################################################################
# GENERATION 7
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 700
# RESULTS: Created 3 pipes, reached a distance of 700
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988122.7981622 vs. 1721989905.7450309
# remaining: 1783
# ######################################################################################################################################################
# GENERATION 8
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 1232
# RESULTS: Created 4 pipes, reached a distance of 1232
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988127.1124303 vs. 1721989905.7450309
# remaining: 1779
# ######################################################################################################################################################
# GENERATION 9
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 658
# RESULTS: Created 2 pipes, reached a distance of 658
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988129.038202 vs. 1721989905.7450309
# remaining: 1777
# ######################################################################################################################################################
# GENERATION 10
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 609
# RESULTS: Created 3 pipes, reached a distance of 609
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988131.066719 vs. 1721989905.7450309
# remaining: 1775
# ######################################################################################################################################################
# GENERATION 11
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 1015
# RESULTS: Created 3 pipes, reached a distance of 1015
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988134.5973682 vs. 1721989905.7450309
# remaining: 1771
# ######################################################################################################################################################
# GENERATION 12
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 679
# RESULTS: Created 3 pipes, reached a distance of 679
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988136.9863415 vs. 1721989905.7450309
# remaining: 1769
# ######################################################################################################################################################
# GENERATION 13
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 616
# RESULTS: Created 2 pipes, reached a distance of 616
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988138.9611897 vs. 1721989905.7450309
# remaining: 1767
# ######################################################################################################################################################
# GENERATION 14
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 693
# RESULTS: Created 3 pipes, reached a distance of 693
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988141.540155 vs. 1721989905.7450309
# remaining: 1764
# ######################################################################################################################################################
# GENERATION 15
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 700
# RESULTS: Created 3 pipes, reached a distance of 700
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988144.0459163 vs. 1721989905.7450309
# remaining: 1762
# ######################################################################################################################################################
# GENERATION 16
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 665
# RESULTS: Created 2 pipes, reached a distance of 665
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988146.1181386 vs. 1721989905.7450309
# remaining: 1760
# ######################################################################################################################################################
# GENERATION 17
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 686
# RESULTS: Created 3 pipes, reached a distance of 686
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988148.7700016 vs. 1721989905.7450309
# remaining: 1757
# ######################################################################################################################################################
# GENERATION 18
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 658
# RESULTS: Created 3 pipes, reached a distance of 658
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988151.0191298 vs. 1721989905.7450309
# remaining: 1755
# ######################################################################################################################################################
# GENERATION 19
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 693
# RESULTS: Created 2 pipes, reached a distance of 693
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988153.0965188 vs. 1721989905.7450309
# remaining: 1753
# ######################################################################################################################################################
# GENERATION 20
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 616
# RESULTS: Created 3 pipes, reached a distance of 616
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988155.40857 vs. 1721989905.7450309
# remaining: 1750
# ######################################################################################################################################################
# GENERATION 21
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 686
# RESULTS: Created 3 pipes, reached a distance of 686
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988157.7691925 vs. 1721989905.7450309
# remaining: 1748
# ######################################################################################################################################################
# GENERATION 22
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 595
# RESULTS: Created 2 pipes, reached a distance of 595
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988159.5182927 vs. 1721989905.7450309
# remaining: 1746
# ######################################################################################################################################################
# GENERATION 23
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 791
# RESULTS: Created 3 pipes, reached a distance of 791
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988162.3122144 vs. 1721989905.7450309
# remaining: 1743
# ######################################################################################################################################################
# GENERATION 24
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 763
# RESULTS: Created 3 pipes, reached a distance of 763
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988164.8931968 vs. 1721989905.7450309
# remaining: 1741
# ######################################################################################################################################################
# GENERATION 25
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 700
# RESULTS: Created 3 pipes, reached a distance of 700
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988167.1082084 vs. 1721989905.7450309
# remaining: 1739
# ######################################################################################################################################################
# GENERATION 26
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 623
# RESULTS: Created 2 pipes, reached a distance of 623
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988168.9247947 vs. 1721989905.7450309
# remaining: 1737
# ######################################################################################################################################################
# GENERATION 27
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 777
# RESULTS: Created 3 pipes, reached a distance of 777
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988171.78886 vs. 1721989905.7450309
# remaining: 1734
# ######################################################################################################################################################
# GENERATION 28
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 616
# RESULTS: Created 3 pipes, reached a distance of 616
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988173.888413 vs. 1721989905.7450309
# remaining: 1732
# ######################################################################################################################################################
# GENERATION 29
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 693
# RESULTS: Created 2 pipes, reached a distance of 693
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988175.9967062 vs. 1721989905.7450309
# remaining: 1730
# ######################################################################################################################################################
# GENERATION 30
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 623
# RESULTS: Created 3 pipes, reached a distance of 623
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988178.2297518 vs. 1721989905.7450309
# remaining: 1728
# ######################################################################################################################################################
# GENERATION 31
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 840
# RESULTS: Created 3 pipes, reached a distance of 840
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988181.0143626 vs. 1721989905.7450309
# remaining: 1725
# ######################################################################################################################################################
# GENERATION 32
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 630
# RESULTS: Created 2 pipes, reached a distance of 630
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988183.040682 vs. 1721989905.7450309
# remaining: 1723
# ######################################################################################################################################################
# GENERATION 33
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 637
# RESULTS: Created 3 pipes, reached a distance of 637
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988185.6545265 vs. 1721989905.7450309
# remaining: 1720
# ######################################################################################################################################################
# GENERATION 34
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 826
# RESULTS: Created 3 pipes, reached a distance of 826
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988188.6309521 vs. 1721989905.7450309
# remaining: 1717
# ######################################################################################################################################################
# GENERATION 35
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 707
# RESULTS: Created 3 pipes, reached a distance of 707
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988191.1119678 vs. 1721989905.7450309
# remaining: 1715
# ######################################################################################################################################################
# GENERATION 36
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 889
# RESULTS: Created 3 pipes, reached a distance of 889
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988194.1284852 vs. 1721989905.7450309
# remaining: 1712
# ######################################################################################################################################################
# GENERATION 37
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 903
# RESULTS: Created 3 pipes, reached a distance of 903
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988197.356011 vs. 1721989905.7450309
# remaining: 1708
# ######################################################################################################################################################
# GENERATION 38
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 686
# RESULTS: Created 3 pipes, reached a distance of 686
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988200.034697 vs. 1721989905.7450309
# remaining: 1706
# ######################################################################################################################################################
# GENERATION 39
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 2156
# RESULTS: Created 6 pipes, reached a distance of 2156
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988211.5709436 vs. 1721989905.7450309
# remaining: 1694
# ######################################################################################################################################################
# GENERATION 40
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 686
# RESULTS: Created 3 pipes, reached a distance of 686
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988214.0792618 vs. 1721989905.7450309
# remaining: 1692
# ######################################################################################################################################################
# GENERATION 41
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 665
# RESULTS: Created 3 pipes, reached a distance of 665
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988216.2667036 vs. 1721989905.7450309
# remaining: 1689
# ######################################################################################################################################################
# GENERATION 42
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 672
# RESULTS: Created 2 pipes, reached a distance of 672
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988218.2956822 vs. 1721989905.7450309
# remaining: 1687
# ######################################################################################################################################################
# GENERATION 43
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 707
# RESULTS: Created 3 pipes, reached a distance of 707
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988220.9479232 vs. 1721989905.7450309
# remaining: 1685
# ######################################################################################################################################################
# GENERATION 44
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 700
# RESULTS: Created 3 pipes, reached a distance of 700
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988223.1584947 vs. 1721989905.7450309
# remaining: 1683
# ######################################################################################################################################################
# GENERATION 45
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 679
# RESULTS: Created 2 pipes, reached a distance of 679
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988225.22197 vs. 1721989905.7450309
# remaining: 1681
# ######################################################################################################################################################
# GENERATION 46
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 672
# RESULTS: Created 3 pipes, reached a distance of 672
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988227.5606308 vs. 1721989905.7450309
# remaining: 1678
# ######################################################################################################################################################
# GENERATION 47
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 672
# RESULTS: Created 3 pipes, reached a distance of 672
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988229.6925104 vs. 1721989905.7450309
# remaining: 1676
# ######################################################################################################################################################
# GENERATION 48
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 931
# RESULTS: Created 3 pipes, reached a distance of 931
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988232.6099508 vs. 1721989905.7450309
# remaining: 1673
# ######################################################################################################################################################
# GENERATION 49
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 700
# RESULTS: Created 3 pipes, reached a distance of 700
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988234.7801685 vs. 1721989905.7450309
# remaining: 1671
# ######################################################################################################################################################
# GENERATION 50
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 1785
# RESULTS: Created 5 pipes, reached a distance of 1785
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988242.0094585 vs. 1721989905.7450309
# remaining: 1664
# ######################################################################################################################################################
# GENERATION 51
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 1246
# RESULTS: Created 4 pipes, reached a distance of 1246
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988246.6756952 vs. 1721989905.7450309
# remaining: 1659
# ######################################################################################################################################################
# GENERATION 52
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 1239
# RESULTS: Created 4 pipes, reached a distance of 1239
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988251.277432 vs. 1721989905.7450309
# remaining: 1654
# ######################################################################################################################################################
# GENERATION 53
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 700
# RESULTS: Created 3 pipes, reached a distance of 700
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988253.6207504 vs. 1721989905.7450309
# remaining: 1652
# ######################################################################################################################################################
# GENERATION 54
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 847
# RESULTS: Created 3 pipes, reached a distance of 847
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988256.3836274 vs. 1721989905.7450309
# remaining: 1649
# ######################################################################################################################################################
# GENERATION 55
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 1183
# RESULTS: Created 4 pipes, reached a distance of 1183
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988260.5914276 vs. 1721989905.7450309
# remaining: 1645
# ######################################################################################################################################################
# GENERATION 56
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 4921
# RESULTS: Created 13 pipes, reached a distance of 4921
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988298.0914972 vs. 1721989905.7450309
# remaining: 1608
# ######################################################################################################################################################
# GENERATION 57
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 2443
# RESULTS: Created 7 pipes, reached a distance of 2443
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988310.1401 vs. 1721989905.7450309
# remaining: 1596
# ######################################################################################################################################################
# GENERATION 58
# ...
# The best Bird of Generation 31 achieved a distance of 4865
# RESULTS: Created 13 pipes, reached a distance of 4865
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988478.6298509 vs. 1721989905.7450309
# remaining: 1427
# ######################################################################################################################################################
# GENERATION 76
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 1988
# RESULTS: Created 6 pipes, reached a distance of 1988
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988487.3862412 vs. 1721989905.7450309
# remaining: 1418
# ######################################################################################################################################################
# GENERATION 77
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 1589
# RESULTS: Created 5 pipes, reached a distance of 1589
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988493.6407275 vs. 1721989905.7450309
# remaining: 1412
# ######################################################################################################################################################
# GENERATION 78
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 2471
# RESULTS: Created 7 pipes, reached a distance of 2471
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988505.3412807 vs. 1721989905.7450309
# remaining: 1400
# ######################################################################################################################################################
# GENERATION 79
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 1617
# RESULTS: Created 5 pipes, reached a distance of 1617
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988511.696359 vs. 1721989905.7450309
# remaining: 1394
# ######################################################################################################################################################
# GENERATION 80
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 5677
# RESULTS: Created 15 pipes, reached a distance of 5677
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721988558.539477 vs. 1721989905.7450309
# remaining: 1347
# ######################################################################################################################################################
# GENERATION 81
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 19586
# RESULTS: Created 49 pipes, reached a distance of 19586
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989083.7691765 vs. 1721989905.7450309
# remaining: 822
# ######################################################################################################################################################
# GENERATION 82
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 2373
# RESULTS: Created 7 pipes, reached a distance of 2373
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989097.5357807 vs. 1721989905.7450309
# remaining: 808
# ######################################################################################################################################################
# GENERATION 83
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 2772
# RESULTS: Created 8 pipes, reached a distance of 2772
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989116.4927907 vs. 1721989905.7450309
# remaining: 789
# ######################################################################################################################################################
# GENERATION 84
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 5789
# RESULTS: Created 15 pipes, reached a distance of 5789
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989176.908183 vs. 1721989905.7450309
# remaining: 729
# ######################################################################################################################################################
# GENERATION 85
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 1575
# RESULTS: Created 5 pipes, reached a distance of 1575
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989185.07989 vs. 1721989905.7450309
# remaining: 721
# ######################################################################################################################################################
# GENERATION 86
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 13062
# RESULTS: Created 33 pipes, reached a distance of 13062
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989453.966672 vs. 1721989905.7450309
# remaining: 452
# ######################################################################################################################################################
# GENERATION 87
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 1155
# RESULTS: Created 4 pipes, reached a distance of 1155
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989459.6451583 vs. 1721989905.7450309
# remaining: 446
# ######################################################################################################################################################
# GENERATION 88
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 10549
# RESULTS: Created 27 pipes, reached a distance of 10549
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989663.5469728 vs. 1721989905.7450309
# remaining: 242
# ######################################################################################################################################################
# GENERATION 89
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 2009
# RESULTS: Created 6 pipes, reached a distance of 2009
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989678.07734 vs. 1721989905.7450309
# remaining: 228
# ######################################################################################################################################################
# GENERATION 90
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 3703
# RESULTS: Created 10 pipes, reached a distance of 3703
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989715.4778442 vs. 1721989905.7450309
# remaining: 190
# ######################################################################################################################################################
# GENERATION 91
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 5320
# RESULTS: Created 14 pipes, reached a distance of 5320
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989774.782719 vs. 1721989905.7450309
# remaining: 131
# ######################################################################################################################################################
# GENERATION 92
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 686
# RESULTS: Created 3 pipes, reached a distance of 686
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989777.6697743 vs. 1721989905.7450309
# remaining: 128
# ######################################################################################################################################################
# GENERATION 93
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 6503
# RESULTS: Created 17 pipes, reached a distance of 6503
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)
# 1721989853.8767042 vs. 1721989905.7450309
# remaining: 52
# ######################################################################################################################################################
# GENERATION 94
# ######################################################################################################################################################
# Creating the Population
# Population -> __init__ : initialising the brains of the birds
# Generating the Pipes
# Launching the Generation Simulation
# The best Bird of Generation 31 achieved a distance of 9415
# RESULTS: Created 24 pipes, reached a distance of 9415
# Creating the next generation
# Getting the best birds' genomes
# Selected 7 Genomes.
# Creating n_birds new genomes by crossing over the selected genomes
# Mutations on the newbords (mutation rate: 0.02)

# %%
print(f"Best Distances: {max_distances}")
print(f"Time Taken: {end_time - start_time}")

plt.plot(max_distances, 'o-')
plt.title('Distance reached by Generation')
plt.xlabel('Generation')
plt.ylabel('Distance reached by the best Bird')
plt.show()

plt.plot(n_pipes_created, 'o-')
plt.title('Number of Pipes created by Generation')
plt.xlabel('Generation')
plt.ylabel('Number of pipes created')
plt.show()
# Out:
# Best Distances: [581, 581, 679, 637, 483, 588, 630, 700, 1232, 658, 609, 1015, 679, 616, 693, 700, 665, 686, 658, 693, 616, 686, 595, 791, 763, 700, 623, 777, 616, 693, 623, 840, 630, 637, 826, 707, 889, 903, 686, 2156, 686, 665, 672, 707, 700, 679, 672, 672, 931, 700, 1785, 1246, 1239, 700, 847, 1183, 4921, 2443, 1232, 1211, 833, 1568, 2072, 2856, 2772, 2422, 1330, 700, 2506, 1253, 1190, 1155, 2093, 1624, 2863, 4865, 1988, 1589, 2471, 1617, 5677, 19586, 2373, 2772, 5789, 1575, 13062, 1155, 10549, 2009, 3703, 5320, 686, 6503, 9415]
# Time Taken: 1894.7717344760895
